# %% [markdown]
# # Analyzing "7363" Data - Text Clustering
# Author: Nicholas Goldsmith <br>
# Start Date: 20 December 2022 <br>
# Last Updated: 23 December 2022 (cleaned up an earlier draft)

# %% [markdown]
# ## Purpose
# In this Jupyter notebook, I attempt text clustering on some public US government data. I utilized code generated using ChatGPT, in a continued attempt to find a method to see changes in topical areas across years. This analysis was utilized to try out the technique and serve as a reference for future analyses. The point of this script is NOT to make a meaningful analysis of the utilized data. I would recommend https://beta.nsf.gov/about/about-nsf-by-the-numbers or try conducting your own analysis if you are interested in more informative analyses.
# <br><br>
# Disclaimer: The contents of this document do not necessarily represent the views of my employer nor the views of any organization I may be associated with.

# %% [markdown]
# ## Libraries

# %%
# Library needed to work with dataframes
import pandas as pd
# Library needed for some math
import numpy as np
# Libraries needed for clustering and natural language processing
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import word_tokenize

# %% [markdown]
# ## Variables to Define

# %%
num_clusters = 20 # This should be the number of clusters you want

# %% [markdown]
# ## Data
# I am using publically available data. Using the public NSF Award Search (https://nsf.gov/awardsearch/advancedSearch.jsp), I've searched Element Code "7363" and included all active and expired awards. There are 2573 awards in the dataset.

# %%
Awards = pd.read_excel("Awards-2022-12-20.xls") # Reads in the data file

# %%
Awards.info() # Gives the structure of the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2573 entries, 0 to 2572
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AwardNumber              2573 non-null   int64
#  1   Title                    2573 non-null   object
#  2   NSFOrganization          2573 non-null   object
#  3   Program(s)               2573 non-null   object
#  4   StartDate                2573 non-null   object
#  5   LastAmendmentDate        2573 non-null   object
#  6   PrincipalInvestigator    2568 non-null   object
#  7   State                    2573 non-null   object
#  8   Organization             2573 non-null   object
#  9   AwardInstrument          2573 non-null   object
#  10  ProgramManager           2573 non-null   object
#  11  EndDate                  2573 non-null   object
#  12  AwardedAmountToDate      2573 non-null   object
#  13  Co-PIName(s)             773 non-null    object
#  14  PIEmailAddress           2568 non-null   object
#  15  OrganizationStreet       2573 non-null   object
#  16  OrganizationCity         2573 non-null   object
#  17  OrganizationState        2573 non-null   object
#  18  OrganizationZip          2573 non-null   int64
#  19  OrganizationPhone        2573 non-null   int64
#  20  NSFDirectorate           2573 non-null   object
#  21  ProgramElementCode(s)    2573 non-null   object
#  22  ProgramReferenceCode(s)  2538 non-null   object
#  23  ARRAAmount               2573 non-null   object
#  24  Abstract                 2570 non-null   object
# dtypes: int64(3), object(22)
# memory usage: 502.7+ KB

# %% [markdown]
# ### Adding a Year Column

# %%
Awards['Year'] = 0 # Creating a year column with all 0's

# The below uses a for loop to go through every row. It takes the last four characters of
# Start Date and calls them the year
for i in range(0, len(Awards['AwardNumber'])):
    Awards['Year'].at[i] = int(Awards['StartDate'][i][len(Awards['StartDate'][i])-4:])

# %% [markdown]
# ### Year Subsets

# %%
Awards['Year'].unique()
# Out:
# array([2021, 2020, 2016, 2018, 2017, 2022, 2019, 2013, 2014, 2009, 2015,
#        2007, 2006, 2012, 2008, 2010, 2011, 2005, 2004, 2003, 2002, 2023,
#        2001], dtype=int64)

# %%
Awards2015 = Awards[Awards['Year'] == 2015]
Awards2016 = Awards[Awards['Year'] == 2016]
Awards2017 = Awards[Awards['Year'] == 2017]
Awards2018 = Awards[Awards['Year'] == 2018]
Awards2019 = Awards[Awards['Year'] == 2019]
Awards2020 = Awards[Awards['Year'] == 2020]
Awards2021 = Awards[Awards['Year'] == 2021]
Awards2022 = Awards[Awards['Year'] == 2022]

# %% [markdown]
# ## Clustering Text

# %% [markdown]
# ### Clustering a Single Year (2020)

# %% [markdown]
# #### Performing the Clustering

# %%
# Extract the abstracts from the data frame
abstracts = Awards2020['Abstract'].tolist()

# Remove empty strings from the list of abstracts
abstracts = [abstract for abstract in abstracts if abstract != ""]

# Vectorize the abstracts using TF-IDF
vectorizer = TfidfVectorizer()
vectors = vectorizer.fit_transform(abstracts)

# Use k-means to cluster the vectors into num_clusters clusters
kmeans = KMeans(n_clusters=num_clusters)
kmeans.fit(vectors)

# Assign each vector to a cluster
clusters = kmeans.predict(vectors)

# Add the cluster labels to the data frame
Awards2020['Cluster'] = clusters
# Out:
# <ipython-input-8-3b87adc82ba2>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Awards2020['Cluster'] = clusters

# %% [markdown]
# #### Words Associated with each Cluster

# %% [markdown]
# ##### All words

# %%
# Transform the cluster centers back into a list of words
cluster_words = vectorizer.inverse_transform(kmeans.cluster_centers_)

# Sort the words in each cluster by their TF-IDF scores
sorted_words = [sorted(words, key=lambda x: x[1], reverse=True) for words in cluster_words]

# Print the sorted words for each cluster
for i in range(len(sorted_words)):
    print(f"Cluster {i}:")
    print(sorted_words[i])
# Out:
# Cluster 0:
# ['by', 'dynamics', 'symbiotically', 'system', 'existing', 'experience', 'experiments', 'expose', 'extended', 'award', 'evaluation', 'events', 'over', 'augmented', 'cumbersome', 'curriculum', 'guarantee', 'multiple', 'outcomes', 'outreach', 'quality', 'subjective', 'summer', 'support', 'at', 'https', 'statutory', 'students', 'utility', 'as', 'is', 'nsf', 'nsfcns2008646project', 'use', 'user', 'users', 'using', 'are', 'br', 'broad', 'broadening', 'broader', 'crafted', 'criteria', 'framework', 'from', 'organized', 'precise', 'project', 'projects', 'xr', 'equipment', 'application', 'applications', 'spaces', 'sports', 'com', 'combination', 'combine', 'communication', 'community', 'component', 'computing', 'concepts', 'confined', 'connected', 'connectivity', 'considerations', 'contrast', 'contribute', 'domains', 'focused', 'for', 'foundation', 'go', 'goal', 'google', 'holistic', 'home', 'however', 'mostly', 'novel', 'posted', 'potential', 'potentially', 'societal', 'solutions', 'to', 'tools', 'towards', 'workshops', 'world', 'worlds', 'worthy', 'and', 'enable', 'enabling', 'encompassing', 'entertainment', 'environments', 'in', 'include', 'indicators', 'indoor', 'integrated', 'integrating', 'intellectual', 'interactivity', 'into', 'involvement', 'on', 'unleash', 'unprecedented', 'immerse', 'impacts', 'small', 'algorithms', 'plan', 'dissemination', 'mission', 'mixed', 'rigorous', 'simulations', 'sites', 'view', 'virtual', 'will', 'wired', 'wireless', 'with', 'without', 'that', 'the', 'their', 'them', 'then', 'theory', 'these', 'this', 'through', 'thus', 'which', 'of', 'be', 'been', 'being', 'deemed', 'deployment', 'design', 'developed', 'developing', 'development', 'general', 'key', 'learning', 'measures', 'merge', 'merit', 'metrics', 'network', 'networks', 'real', 'realistic', 'reality', 'reflects', 'reinforcement', 'relied', 'research', 'reservoir', 'resource', 'restricts', 'result', 'review', 'seamless', 'seminars', 'service', 'technologies', 'well', 'adapt', 'educational', 'accelerating', 'achieved', 'across', 'activities', 'objective', 'cable', 'camps', 'can', 'carry', 'date', 'gaming', 'hands', 'has', 'have', 'having', 'management', 'marrying', 'narrows', 'part', 'participation', 'particular', 'ranging', 'tangible', 'validated']
# Cluster 1:
# ['by', 'systems', 'excess', 'expected', 'experience', 'award', 'two', 'evaluation', 'culminate', 'current', 'fully', 'fundamental', 'much', 'multitude', 'our', 'published', 'pushed', 'quality', 'quantum', 'such', 'support', 'at', 'it', 'statutory', 'students', 'study', 'as', 'aspects', 'aspires', 'especially', 'is', 'nsf', 'rsa', 'users', 'using', 'are', 'area', 'areas', 'br', 'bridge', 'broad', 'broader', 'criteria', 'cryptography', 'ground', 'groups', 'practical', 'practice', 'practitioners', 'precision', 'primarily', 'problem', 'processing', 'progress', 'project', 'promise', 'proposal', 'proposed', 'protocols', 'provide', 'application', 'applications', 'operation', 'optical', 'optimized', 'space', 'specifications', 'speedups', 'up', 'book', 'boosted', 'both', 'coherence', 'combining', 'communication', 'communications', 'communities', 'community', 'completely', 'computation', 'computer', 'computing', 'concepts', 'connecting', 'conquer', 'constraints', 'contemporary', 'conventional', 'down', 'focuses', 'for', 'form', 'formats', 'foundation', 'goal', 'models', 'modulation', 'most', 'no', 'noise', 'polynomial', 'posed', 'possible', 'role', 'routing', 'society', 'to', 'today', 'tools', 'topics', 'worthy', 'an', 'analogues', 'analysis', 'anchored', 'and', 'enable', 'enabled', 'encompasses', 'encryption', 'end', 'energy', 'engineering', 'ensuring', 'entanglement', 'in', 'include', 'inform', 'information', 'informed', 'infrastructure', 'intellectual', 'interested', 'internet', 'involved', 'on', 'ones', 'under', 'understanding', 'emerging', 'immediate', 'impacts', 'implications', 'important', 'umbrella', 'algorithms', 'allocation', 'allow', 'already', 'alternative', 'classical', 'play', 'ultra', 'qkd', 'big', 'direction', 'discovery', 'distributed', 'distribution', 'high', 'higher', 'him', 'ligo', 'like', 'limits', 'mission', 'pi', 'risk', 'single', 'time', 'times', 'will', 'with', 'channel', 'channels', 'characterization', 'phase', 'photon', 'physical', 'physics', 'shared', 'than', 'that', 'the', 'their', 'theory', 'there', 'these', 'this', 'through', 'which', 'who', 'of', 'be', 'because', 'been', 'between', 'decades', 'deemed', 'deep', 'deployment', 'design', 'detector', 'develop', 'developing', 'development', 'device', 'help', 'key', 'lead', 'memory', 'merit', 'metrics', 'metrology', 'needs', 'network', 'networking', 'networks', 'new', 'perform', 'performance', 'perspective', 'recent', 'reflects', 'relating', 'relationship', 'reliable', 'requirements', 'research', 'researchers', 'resource', 'respective', 'results', 'review', 'revolutionizing', 'seamless', 'search', 'secure', 'semiclassical', 'sensing', 'serve', 'set', 'technologies', 'technology', 'telecommunications', 'well', 'addition', 'advance', 'advanced', 'advances', 'accessible', 'activities', 'economy', 'scale', 'science', 'based', 'capacity', 'catalyze', 'data', 'family', 'gap', 'has', 'have', 'large', 'layer', 'major', 'make', 'many', 'pairs', 'range', 'rate', 'same', 'value', 'various', 'wave', 'way']
# Cluster 2:
# ['by', 'cyberphysical', 'cycle', 'dynamic', 'dynamically', 'dynamics', 'system', 'systematic', 'systematically', 'systems', 'typically', 'exacerbates', 'examples', 'execution', 'existing', 'expanded', 'expected', 'experience', 'experiments', 'exploit', 'explore', 'extend', 'award', 'dwindling', 'availability', 'evaluate', 'evaluated', 'evaluation', 'events', 'evict', 'evolving', 'iv', 'over', 'overall', 'overcome', 'tvsa', 'augmented', 'automation', 'autonomous', 'build', 'business', 'but', 'cu', 'current', 'curricula', 'du', 'due', 'dus', 'full', 'fully', 'functional', 'functionality', 'fundamental', 'fundamentally', 'future', 'guaranteed', 'guarantees', 'human', 'hundreds', 'much', 'multi', 'multimedia', 'multiple', 'must', 'number', 'outcomes', 'outdoor', 'purview', 'qualitatively', 'quality', 'questions', 'queueing', 'substantial', 'succeed', 'successful', 'such', 'suited', 'superior', 'support', 'supported', 'supporting', 'turns', 'at', 'etc', 'it', 'its', 'lte', 'other', 'standard', 'statutory', 'still', 'storage', 'store', 'strategies', 'streaming', 'streamline', 'street', 'stringent', 'students', 'studied', 'studies', 'study', 'utilization', 'utilizes', 'utilizing', 'as', 'assessed', 'assessment', 'assets', 'assignment', 'establish', 'established', 'is', 'isolation', 'issues', 'nsf', 'tsva', 'us', 'use', 'used', 'user', 'users', 'using', 'ar', 'are', 'array', 'artificial', 'br', 'bring', 'broader', 'create', 'creating', 'creation', 'creative', 'criteria', 'critical', 'cross', 'crucial', 'driven', 'driving', 'framework', 'free', 'freedom', 'frequency', 'from', 'gradually', 'growing', 'growth', 'or', 'order', 'practical', 'predominant', 'presence', 'pressure', 'pricing', 'primary', 'principles', 'prior', 'problem', 'problems', 'process', 'processes', 'processing', 'processors', 'professional', 'professionals', 'program', 'progressive', 'project', 'promising', 'propagation', 'properties', 'proposed', 'proposing', 'prototyping', 'provable', 'provably', 'provide', 'providing', 'provisioning', 'proximity', 'tradeoffs', 'traffic', 'train', 'transform', 'transformation', 'transmission', 'transmit', 'transportation', 'equivalent', 'application', 'applications', 'appreciate', 'approach', 'operation', 'operations', 'optics', 'optimal', 'optimization', 'optimize', 'optimized', 'space', 'specific', 'specifically', 'spectral', 'spectrum', 'speed', 'speeds', 'split', 'splitting', 'boost', 'boosting', 'both', 'bounds', 'co', 'coding', 'coexistence', 'collection', 'collocated', 'commercial', 'committed', 'communication', 'compensate', 'competitiveness', 'complementary', 'complex', 'components', 'composed', 'composing', 'composite', 'comprehensive', 'computation', 'computers', 'computing', 'concept', 'conditions', 'connecticut', 'connectivity', 'consider', 'considering', 'considers', 'consists', 'constantly', 'constraints', 'consumer', 'consumption', 'content', 'context', 'continuity', 'contribute', 'control', 'conventional', 'convex', 'cost', 'costly', 'coverage', 'down', 'focuses', 'following', 'footprints', 'for', 'form', 'formulating', 'foundation', 'goals', 'good', 'holistic', 'homes', 'host', 'hosting', 'how', 'however', 'iot', 'iots', 'joint', 'jointly', 'low', 'mobile', 'mobility', 'modelling', 'models', 'moderate', 'modulation', 'motivated', 'move', 'normal', 'not', 'novel', 'nowadays', 'points', 'pool', 'popular', 'popularity', 'populated', 'portability', 'portable', 'portions', 'position', 'potential', 'power', 'robots', 'robust', 'robustness', 'routing', 'software', 'solutions', 'solving', 'sophisticated', 'sources', 'to', 'today', 'together', 'tools', 'towards', 'women', 'work', 'works', 'worthy', 'an', 'analytical', 'and', 'anomaly', 'antenna', 'antennas', 'enable', 'enabled', 'enables', 'enabling', 'encompasses', 'end', 'endpoints', 'energy', 'engineers', 'environment', 'environments', 'envisions', 'in', 'include', 'including', 'incorporate', 'increase', 'increasingly', 'indicators', 'individual', 'indoor', 'industrial',  ...
# Cluster 3:
# ['by', 'dynamic', 'dynamics', 'eyes', 'hybrid', 'hyperdimensional', 'symbol', 'synergy', 'system', 'systems', 'types', 'examine', 'examines', 'example', 'execution', 'exhibit', 'existing', 'exogenous', 'expected', 'experience', 'experiences', 'explicit', 'exploit', 'extended', 'extensive', 'external', 'extreme', 'extremely', 'award', 'aware', 'awareness', 'two', 'available', 'evaluate', 'evaluated', 'evaluating', 'evaluation', 'evaluations', 'even', 'ever', 'everyone', 'evolve', 'over', 'overall', 'overcome', 'overcoming', 'overflow', 'overhead', 'augment', 'augmented', 'authorization', 'autoencoders', 'automated', 'autonomous', 'build', 'building', 'built', 'bulky', 'buried', 'but', 'current', 'curriculum', 'due', 'fully', 'function', 'fundamental', 'fundamentally', 'furthermore', 'future', 'guaranteed', 'guarantees', 'human', 'much', 'multi', 'number', 'numbers', 'numerical', 'nutrition', 'our', 'out', 'outcome', 'outdoors', 'output', 'outreach', 'outset', 'public', 'pursue', 'quality', 'quantity', 'rural', 'sub', 'subproblems', 'subset', 'success', 'such', 'suitable', 'supervised', 'supervision', 'supply', 'support', 'supporting', 'surrounding', 'suspicious', 'tunes', 'tuning', 'at', 'it', 'its', 'other', 'stability', 'standard', 'state', 'stationary', 'stations', 'statistical', 'statistics', 'statutory', 'stem', 'steps', 'stochastic', 'stored', 'straining', 'strategies', 'stringent', 'strong', 'structural', 'structure', 'students', 'utilities', 'utility', 'utilize', 'utilized', 'as', 'ase', 'aspect', 'assess', 'assessments', 'assimilate', 'associated', 'association', 'assumptions', 'asymmetric', 'asynchronous', 'especially', 'essential', 'establish', 'establishes', 'estimation', 'is', 'isolated', 'issues', 'nsf', 'usage', 'use', 'used', 'useful', 'user', 'users', 'uses', 'using', 'usually', 'ar', 'arbitrary', 'architecture', 'architectures', 'are', 'area', 'areas', 'arrivals', 'art', 'artificial', 'br', 'brain', 'breakthroughs', 'bridge', 'bring', 'brings', 'broad', 'broadened', 'broader', 'create', 'creating', 'credentials', 'criteria', 'critical', 'cross', 'crowded', 'crucial', 'dramatic', 'dramatically', 'drive', 'driven', 'driving', 'error', 'errors', 'framework', 'free', 'frequency', 'frequently', 'from', 'frontier', 'gradient', 'graduate', 'great', 'greatly', 'grid', 'growth', 'or', 'order', 'oregon', 'practice', 'practitioners', 'precision', 'predict', 'predictions', 'present', 'presents', 'preserving', 'prevent', 'principled', 'principles', 'privacy', 'probabilistic', 'problem', 'problems', 'procedure', 'process', 'processed', 'processes', 'professional', 'profits', 'programs', 'project', 'projects', 'proliferation', 'prolong', 'promote', 'propagated', 'proposed', 'proposes', 'prototyping', 'provide', 'provides', 'providing', 'track', 'tracking', 'trade', 'tradeoff', 'traditionally', 'traffic', 'training', 'transceiver', 'transform', 'transformative', 'transforms', 'transmission', 'transmitters', 'transmitting', 'transportation', 'transported', 'trends', 'truly', 'trust', 'trusted', 'try', 'urban', 'vr', 'iq', 'applications', 'applied', 'applying', 'apprenticeships', 'approach', 'approaches', 'episodes', 'ip', 'open', 'openwfl', 'operate', 'operations', 'opportunistic', 'opportunities', 'opportunity', 'optimal', 'optimally', 'optimization', 'optimizing', 'space', 'sparsification', 'spatial', 'specific', 'specifically', 'specifications', 'specified', 'spectral', 'spectrum', 'speed', 'spot', 'up', 'update', 'updates', 'upon', 'body', 'both', 'collaborative', 'collaboratively', 'collegiate', 'combine', 'come', 'comes', 'comfort', 'commoditize', 'commonalities', 'commonplace', 'communicate', 'communicated', 'communication', 'communications', 'communities', 'community', 'comparative', 'compensate', 'compensates', 'competing', 'complementary', 'completed', 'complex', 'complexity', 'component', 'comprehensive', 'comprehensively', 'compression', 'compressor', 'computation', 'computational', 'computationally', 'computations ...
# Cluster 4:
# ['by', 'system', 'systems', 'existing', 'expenditure', 'experienced', 'expertise', 'exploration', 'explore', 'exploring', 'award', 'available', 'evaluation', 'even', 'everyday', 'overall', 'overarching', 'oversimplify', 'but', 'current', 'due', 'further', 'future', 'hundreds', 'multi', 'multiple', 'numbers', 'our', 'output', 'outside', 'public', 'pushed', 'questions', 'queueing', 'quickly', 'rules', 'substantially', 'support', 'supporting', 'supports', 'at', 'etc', 'it', 'its', 'stack', 'standardization', 'statutory', 'stochastic', 'strategy', 'strives', 'strong', 'students', 'studies', 'as', 'aspect', 'aspects', 'established', 'is', 'nsf', 'useless', 'users', 'using', 'are', 'areas', 'artificial', 'br', 'bridge', 'broaden', 'broader', 'criteria', 'critical', 'cross', 'crucial', 'drone', 'droughts', 'framework', 'frequency', 'from', 'ground', 'groups', 'growing', 'growth', 'or', 'practice', 'prediction', 'present', 'presented', 'principal', 'problem', 'problems', 'processing', 'program', 'programs', 'project', 'proliferation', 'proposed', 'protecting', 'protocol', 'protocols', 'provides', 'tractable', 'traffic', 'trained', 'training', 'transceivers', 'translated', 'transmitter', 'transport', 'transportation', 'truth', 'applicable', 'application', 'applications', 'approach', 'operate', 'operations', 'optimal', 'optimally', 'optimization', 'optimized', 'sparse', 'sparsity', 'specifically', 'spectrum', 'up', 'upper', 'bodies', 'bounds', 'co', 'coexist', 'coexistence', 'collaboration', 'collected', 'collecting', 'collectively', 'combines', 'commerce', 'communication', 'communications', 'communities', 'community', 'companies', 'complementary', 'complex', 'complexity', 'comprehension', 'computer', 'computing', 'congestion', 'conjunction', 'considerations', 'consists', 'constraints', 'continuously', 'contribute', 'control', 'could', 'focus', 'following', 'for', 'forecasting', 'formal', 'foundation', 'goal', 'holistic', 'hop', 'host', 'how', 'however', 'joint', 'low', 'mobile', 'model', 'modeling', 'models', 'modern', 'moisture', 'monitoring', 'more', 'most', 'mostly', 'not', 'novel', 'poor', 'positioned', 'routing', 'so', 'society', 'soil', 'to', 'volume', 'workshop', 'worst', 'worthy', 'analysis', 'analytic', 'analytics', 'and', 'answer', 'antennas', 'enable', 'encompasses', 'end', 'energy', 'engineering', 'enlarge', 'in', 'including', 'increase', 'increased', 'increases', 'inculcate', 'indispensable', 'industry', 'inferences', 'information', 'inject', 'input', 'institutions', 'instruction', 'intellectual', 'intelligence', 'interference', 'internet', 'interrelated', 'into', 'introduces', 'investigator', 'knowledge', 'on', 'one', 'only', 'underlying', 'underrepresented', 'understanding', 'unfortunately', 'unified', 'unique', 'emerging', 'employ', 'impacts', 'implement', 'important', 'improve', 'improved', 'smartphones', 'algorithms', 'all', 'allow', 'along', 'also', 'classroom', 'climate', 'floods', 'ml', 'plethora', 'ai', 'aims', 'bit', 'different', 'direction', 'disciplinary', 'distributed', 'finding', 'findings', 'gigabit', 'ii', 'iii', 'kind', 'life', 'likewise', 'limited', 'limits', 'linear', 'mimo', 'minority', 'mission', 'mitigation', 'pi', 'pioneer', 'pipes', 'pis', 'signal', 'significant', 'time', 'virtualization', 'vision', 'wide', 'will', 'wireless', 'with', 'challenges', 'channel', 'characteristics', 'physical', 'shape', 'shared', 'sharing', 'that', 'the', 'their', 'them', 'theme', 'theoretical', 'theory', 'there', 'thereby', 'these', 'this', 'thousands', 'three', 'through', 'throughput', 'thrust', 'thrusts', 'where', 'which', 'while', 'agricultural', 'ignore', 'efficiency', 'efficient', 'efforts', 'of', 'offline', 'often', 'rf', 'rfi', 'be', 'been', 'best', 'between', 'cellular', 'dedicated', 'deemed', 'deep', 'defense', 'delay', 'demands', 'depends', 'design', 'designing', 'designs', 'detection', 'develop', 'developing', 'development', 'develops', 'devices', 'general', 'generate', 'generation', 'health', 'heavily', 'hen ...
# Cluster 5:
# ['by', 'dynamic', 'dynamics', 'hybrid', 'system', 'systems', 'except', 'exchange', 'execution', 'exhaustive', 'exist', 'existing', 'exists', 'exogenous', 'expected', 'expensive', 'explore', 'exploring', 'exponential', 'extensive', 'extent', 'extracted', 'extraordinary', 'award', 'own', 'switch', 'switches', 'switching', 'two', 'availability', 'available', 'avoid', 'avoiding', 'eva', 'evaluation', 'ever', 'over', 'bufferless', 'build', 'businesses', 'but', 'cure', 'current', 'currently', 'curriculum', 'customer', 'due', 'duration', 'during', 'fueled', 'function', 'fundamental', 'fundamentally', 'funded', 'funding', 'further', 'furthermore', 'future', 'human', 'mu', 'much', 'multi', 'multiple', 'must', 'number', 'numerous', 'our', 'out', 'outcomes', 'outdated', 'outreach', 'public', 'publications', 'publicly', 'published', 'qualitative', 'quality', 'questions', 'rural', 'subject', 'subjective', 'successful', 'such', 'suffered', 'support', 'surges', 'sustain', 'sustained', 'sustaining', 'vulnerabilities', 'at', 'attacks', 'attempts', 'attention', 'etc', 'https', 'it', 'its', 'other', 'state', 'states', 'statistical', 'statutory', 'step', 'still', 'stochastic', 'storage', 'strain', 'strategies', 'strengths', 'stress', 'students', 'studies', 'study', 'utilization', 'as', 'aspects', 'assess', 'assumption', 'cs', 'essential', 'gs', 'is', 'isolation', 'issues', 'nsf', 'ossp', 'us', 'usable', 'usage', 'use', 'used', 'useful', 'using', 'architecture', 'architectures', 'are', 'area', 'areas', 'arise', 'around', 'arrivals', 'artifacts', 'br', 'broad', 'broadband', 'broaden', 'broader', 'brought', 'created', 'crisis', 'criteria', 'critical', 'crucial', 'dramatic', 'dramatically', 'driver', 'drug', 'fractions', 'framework', 'free', 'from', 'grained', 'granular', 'greatest', 'grow', 'growth', 'or', 'order', 'orders', 'organizations', 'predict', 'predicted', 'prediction', 'predictive', 'preemptive', 'prepare', 'prevailing', 'previous', 'previously', 'primarily', 'prior', 'prioritizing', 'privacy', 'private', 'probability', 'problem', 'problems', 'process', 'processes', 'processing', 'produce', 'programs', 'project', 'proposal', 'propriety', 'prosperity', 'prototype', 'provide', 'providers', 'provides', 'providing', 'traditional', 'traffic', 'training', 'transfer', 'transmission', 'transmit', 'transmitters', 'treatment', 'trends', 'tribal', 'try', 'urban', 'appears', 'application', 'applications', 'apply', 'approach', 'approximation', 'epoch', 'np', 'open', 'opened', 'operate', 'operation', 'operator', 'operators', 'opportunities', 'optical', 'optimal', 'optimally', 'optimization', 'optimize', 'span', 'spanning', 'specifically', 'spectrum', 'speed', 'speedup', 'spread', 'up', 'upgrade', 'both', 'code', 'com', 'combine', 'combined', 'come', 'coming', 'commodity', 'communities', 'community', 'compare', 'comparing', 'comparisons', 'complementary', 'completion', 'complex', 'compliance', 'comprised', 'computation', 'compute', 'computers', 'computing', 'conducted', 'conferencing', 'conflict', 'congestion', 'connectivity', 'considerable', 'contain', 'content', 'continue', 'convenient', 'coordination', 'corresponding', 'cost', 'could', 'course', 'courses', 'covid', 'covid19', 'do', 'does', 'focus', 'following', 'for', 'forefront', 'form', 'found', 'foundation', 'foundations', 'fourth', 'goal', 'government', 'governments', 'hold', 'home', 'host', 'how', 'however', 'io', 'load', 'local', 'location', 'long', 'longer', 'low', 'mobile', 'modeled', 'modeling', 'models', 'modules', 'monitoring', 'more', 'most', 'no', 'non', 'not', 'points', 'policies', 'poor', 'population', 'portfolios', 'ports', 'possible', 'posted', 'role', 'roughly', 'so', 'social', 'society', 'socioeconomic', 'software', 'solutions', 'solves', 'some', 'source', 'sources', 'to', 'today', 'too', 'tool', 'tools', 'towards', 'volume', 'volumes', 'work', 'workforce', 'workloads', 'workshop', 'world', 'worldwide', 'worst', 'worthy', 'an', 'analysis', 'analyzing', 'and', 'answers', 'any', 'anyt ...
# Cluster 6:
# ['by', 'symposium', 'system', 'systems', 'types', 'existing', 'experience', 'explore', 'expose', 'exposed', 'exposure', 'extends', 'tx', 'award', 'awards', 'twenty', 'two', 'available', 'evaluation', 'event', 'events', 'evolving', 'audience', 'austin', 'budapest', 'build', 'but', 'cultural', 'due', 'during', 'fundamental', 'funding', 'funds', 'further', 'future', 'hungary', 'june', 'junior', 'our', 'public', 'published', 'quality', 'questions', 'quickly', 'substantially', 'support', 'supports', 'at', 'attend', 'attendance', 'attendees', 'attending', 'attention', 'ethical', 'ethnicity', 'it', 'other', 'otherwise', 'stage', 'state', 'states', 'statutory', 'storage', 'strongly', 'student', 'students', 'utilize', 'as', 'aspects', 'association', 'assumptions', 'establish', 'is', 'issues', 'nsdi', 'nsf', 'us', 'usa', 'used', 'usenix', 'using', '3rd', 'are', 'area', 'areas', 'around', 'art', 'br', 'breaking', 'bring', 'bringing', 'brings', 'broad', 'broaden', 'broader', 'broadly', 'criteria', 'critiques', 'cross', 'france', 'freely', 'from', 'frontier', 'graduate', 'grant', 'grants', 'ground', 'group', 'groups', 'or', 'organization', 'organized', 'organizes', 'original', 'practical', 'practitioners', 'presentations', 'presented', 'presenting', 'principles', 'prior', 'priority', 'problems', 'processing', 'professionals', 'program', 'progress', 'project', 'promising', 'promoting', 'proposes', 'protocols', 'provide', 'provides', 'traditional', 'traditionally', 'training', 'travel', 'trends', 'application', 'applications', 'approaches', 'april', 'open', 'operating', 'operations', 'opportunities', 'opportunity', 'spain', 'special', 'specification', 'up', 'boston', 'both', 'collaboration', 'collaborations', 'committee', 'communication', 'community', 'competition', 'complex', 'computer', 'computing', 'conference', 'conferences', 'consist', 'construction', 'constructive', 'containing', 'content', 'contributions', 'country', 'covers', 'domain', 'focus', 'focuses', 'following', 'for', 'forum', 'foster', 'foundation', 'government', 'hotmobile', 'jose', 'long', 'lowering', 'mobile', 'modeling', 'noms', 'normally', 'northeastern', 'not', 'population', 'possible', 'poster', 'role', 'routing', 'social', 'sosr', 'to', 'together', 'tools', 'top', 'topics', 'tough', 'towards', 'work', 'workforce', 'working', 'workshop', 'world', 'worldwide', 'worthy', 'would', 'young', 'an', 'analysis', 'and', 'annually', 'enables', 'enabling', 'encouraged', 'encourages', 'engineering', 'engineers', 'in', 'include', 'including', 'individual', 'industrial', 'industry', 'information', 'initiated', 'innovation', 'inspire', 'inspired', 'institute', 'institutions', 'integration', 'intellectual', 'interact', 'interest', 'interesting', 'interests', 'international', 'internet', 'interprets', 'into', 'introducing', 'investment', 'knowledge', 'on', 'only', 'unable', 'unavailability', 'under', 'underrepresented', 'understanding', 'unexpected', 'united', 'unites', 'universities', 'university', 'unlikely', 'unproven', 'impact', 'impacts', 'implementation', 'important', 'improvement', 'all', 'allows', 'also', 'clara', 'cloud', 'electrical', 'electronics', 'place', 'play', 'aims', 'bi', 'different', 'difficult', 'directing', 'directions', 'disciplinary', 'discuss', 'discusses', 'discussing', 'discussions', 'distributed', 'diversity', 'field', 'fields', 'file', 'financial', 'find', 'first', 'given', 'high', 'highlight', 'highly', 'life', 'likely', 'limited', 'might', 'minority', 'mission', 'pipeline', 'sigcomm', 'sigmetrics', 'similar', 'since', 'tier', 'time', 'visions', 'wide', 'will', 'wireless', 'wise', 'with', 'challenges', 'shape', 'share', 'shared', 'that', 'the', 'their', 'them', 'there', 'these', 'they', 'this', 'through', 'thus', 'which', 'who', 'ifip', 'of', 'offered', 'offers', 'often', 'be', 'been', 'benefit', 'between', 'center', 'centric', 'debunks', 'deemed', 'deployment', 'design', 'develop', 'features', 'february', 'federation', 'female', 'gender', 'generated', 'get ...
# Cluster 7:
# ['by', 'dynamic', 'system', 'systems', 'example', 'exceed', 'exciting', 'existing', 'experiments', 'exploit', 'exploits', 'explores', 'expose', 'extremely', 'award', 'aware', 'own', 'evaluated', 'evaluation', 'over', 'augmented', 'automated', 'automotive', 'autonomous', 'building', 'but', 'culminating', 'curricula', 'functions', 'fundamental', 'human', 'hundreds', 'multi', 'must', 'numerous', 'outcomes', 'outdoor', 'outreach', 'publication', 'qualcomm', 'such', 'support', 'surrounding', 'at', 'etc', 'it', 'its', 'other', 'stack', 'statutory', 'strategies', 'strictly', 'strides', 'students', 'studies', 'as', 'assist', 'assistance', 'association', 'is', 'isolating', 'nsf', 'use', 'uses', 'using', 'architecture', 'architectures', 'are', 'area', 'areas', 'br', 'broad', 'broadening', 'broader', 'crenshaw', 'criteria', 'driver', 'driving', 'from', 'granularities', 'greatly', 'grid', 'groups', 'or', 'practice', 'predictable', 'processed', 'programs', 'project', 'provide', 'providing', 'trade', 'traffic', 'train', 'transfer', 'transmission', 'trucks', 'equipped', 'applications', 'approach', 'approaches', 'approximately', 'space', 'specifically', 'spectrum', 'upon', 'bottleneck', 'collaboration', 'communication', 'communications', 'compelling', 'complex', 'component', 'components', 'composite', 'computing', 'constraints', 'contribute', 'control', 'conventional', 'cooperative', 'coordinate', 'correspondence', 'cosmos', 'coverage', 'for', 'foundation', 'however', 'localization', 'los', 'low', 'modal', 'models', 'montebello', 'more', 'motors', 'not', 'point', 'poisoning', 'potential', 'road', 'roadside', 'robotics', 'robust', 'robustness', 'so', 'socially', 'societal', 'south', 'to', 'today', 'tools', 'topics', 'towards', 'world', 'worthy', 'an', 'and', 'angeles', 'annually', 'enabled', 'energy', 'engage', 'enhance', 'enhanced', 'ensure', 'ensuring', 'environment', 'in', 'includes', 'including', 'incorporate', 'increase', 'increasingly', 'independent', 'individual', 'indoor', 'industry', 'information', 'infrastructure', 'innovations', 'institution', 'integrated', 'intellectual', 'internship', 'into', 'involving', 'knowledge', 'on', 'under', 'undergraduates', 'underrepresented', 'unfortunately', 'unified', 'unprecedented', 'unusual', 'images', 'impact', 'impacts', 'implemented', 'improve', 'improved', 'algorithms', 'all', 'also', 'blend', 'blending', 'blends', 'blocked', 'glimpse', 'glimpses', 'globally', 'platform', 'aid', 'bicycles', 'different', 'directly', 'disseminating', 'district', 'diverse', 'either', 'first', 'given', 'high', 'highly', 'line', 'link', 'lives', 'miles', 'million', 'mission', 'mixed', 'rich', 'richness', 'sight', 'signaling', 'significant', 'simultaneous', 'situations', 'via', 'view', 'views', 'visual', 'will', 'wireless', 'with', 'within', 'challenge', 'challenges', 'channel', 'phd', 'physical', 'share', 'than', 'that', 'the', 'their', 'them', 'then', 'these', 'this', 'three', 'through', 'thrusts', 'wheelers', 'when', 'which', 'while', '5g', 'effectively', 'efforts', 'of', 'off', 'be', 'been', 'benefit', 'between', 'beyond', 'cellular', 'central', 'decisions', 'deemed', 'dense', 'dependability', 'design', 'designing', 'designs', 'detail', 'determine', 'develop', 'develops', 'general', 'generate', 'geometric', 'geometry', 'key', 'learning', 'levels', 'mentor', 'merit', 'methods', 'needed', 'network', 'networking', 'pedestrians', 'perceive', 'perception', 'performance', 'reality', 'received', 'recognition', 'reflects', 'relevant', 'reliable', 'relies', 'rely', 'remains', 'represent', 'representation', 'representations', 'represented', 'requirements', 'research', 'resolve', 'respecting', 'resulting', 'results', 'retain', 'review', 'seamless', 'see', 'seeking', 'seeks', 'sensing', 'sensor', 'sensors', 'separate', 'set', 'setting', 'team', 'techniques', 'technologies', 'technology', 'tension', 'testbed', 'vehicle', 'vehicles', 'vehicular', 'we', '3d', 'addition', 'address', 'advanced', 'advantages', 'education', 'educat ...
# Cluster 8:
# ['by', 'bypass', 'bytecode', 'cyber', 'cyberattacks', 'dynamic', 'dynamically', 'dynamics', 'synchronizing', 'synchronous', 'system', 'systematic', 'systematically', 'systems', 'types', 'exactly', 'examine', 'example', 'examples', 'exchange', 'executed', 'existence', 'existing', 'expand', 'expected', 'experiments', 'expertise', 'explain', 'exploitation', 'exploits', 'explore', 'explores', 'exploring', 'exponentially', 'exposes', 'expressive', 'extending', 'external', 'extracted', 'extracting', 'extraction', 'ixps', 'award', 'own', 'owns', 'switch', 'switches', 'two', 'www', 'available', 'dv', 'evaluate', 'evaluating', 'evaluation', 'even', 'event', 'events', 'ever', 'evolutionary', 'over', 'overcome', 'overheads', 'overlaid', 'overlay', 'overseas', 'overwhelming', 'augmented', 'authentication', 'automated', 'automatically', 'automation', 'build', 'building', 'built', 'businesses', 'but', 'current', 'currently', 'curriculum', 'custom', 'during', 'full', 'fully', 'function', 'functionality', 'functions', 'fundamental', 'fundamentally', 'further', 'future', 'guarantee', 'guess', 'human', 'humans', 'hundreds', 'hurricanes', 'justify', 'mu', 'much', 'multi', 'multipath', 'multiple', 'must', 'number', 'numbers', 'our', 'out', 'outage', 'outages', 'outcome', 'output', 'outputs', 'outreach', 'public', 'publish', 'purchases', 'purposes', 'pursue', 'quality', 'quantify', 'quantitative', 'queries', 'query', 'questioned', 'queues', 'queuing', 'quick', 'quickly', 'run', 'running', 'rural', 'subject', 'subscribe', 'substantially', 'subtle', 'successful', 'such', 'suffer', 'suggests', 'suitable', 'suited', 'summer', 'support', 'supporting', 'supports', 'susceptible', 'tunneling', 'vulnerabilities', 'vulnerability', 'at', 'attacker', 'attacks', 'attractive', 'attribute', 'ethical', 'http', 'https', 'it', 'items', 'its', 'other', 'stacks', 'stagnated', 'standard', 'standards', 'state', 'statistical', 'statutory', 'step', 'steps', 'still', 'stimulating', 'stokes', 'store', 'stored', 'strategies', 'strong', 'strongest', 'structural', 'structures', 'struggling', 'students', 'studies', 'study', 'utilize', 'as', 'aspects', 'assess', 'assist', 'associated', 'assumes', 'assumption', 'assumptions', 'astronomically', 'asynchronous', 'cs', 'csma', 'is', 'isolate', 'isolated', 'isolation', 'isps', 'issue', 'issues', 'issuing', 'nsf', 'osu', 'us', 'use', 'used', 'useful', 'user', 'users', 'uses', 'using', 'ar', 'architecting', 'architects', 'architecture', 'archival', 'are', 'area', 'areas', 'array', 'art', 'artificial', 'br', 'bradycardia', 'brand', 'breakdowns', 'breathing', 'bridge', 'broad', 'broaden', 'broader', 'broadly', 'browsers', 'crack', 'create', 'created', 'creating', 'creative', 'criteria', 'critical', 'critically', 'cross', 'cryptography', 'dramatically', 'drive', 'driven', 'drivers', 'drugs', 'errors', 'fraction', 'fragment', 'framework', 'frameworks', 'freshness', 'friendliness', 'from', 'graduate', 'grain', 'graph', 'greater', 'group', 'groups', 'grow', 'growth', 'or', 'order', 'organization', 'organizations', 'orientations', 'oriented', 'practical', 'practice', 'predictability', 'predictable', 'predicting', 'preferred', 'preliminary', 'present', 'presents', 'preserved', 'primary', 'privacy', 'private', 'probes', 'probing', 'problem', 'problematic', 'problems', 'process', 'processes', 'processing', 'processor', 'processors', 'produce', 'produced', 'program', 'programmability', 'programmable', 'programmers', 'programs', 'project', 'projects', 'proliferation', 'promise', 'promising', 'pronged', 'propagating', 'properly', 'proposal', 'proposed', 'proposes', 'protect', 'protected', 'protein', 'protocol', 'protocols', 'prototype', 'prototypes', 'proves', 'provide', 'provider', 'providers', 'providing', 'provision', 'sram', 'track', 'traffic', 'training', 'transform', 'transformed', 'transients', 'translated', 'transmission', 'transmit', 'transport', 'trend', 'written', 'apart', 'apnea', 'appeal', 'appear', 'appliances', 'application', 'applic ...
# Cluster 9:
# ['by', 'system', 'systems', 'exist', 'existing', 'expected', 'experimental', 'experimentally', 'experimentation', 'exploitation', 'exploiting', 'award', 'avoidance', 'evaluation', 'evidenced', 'evolution', 'over', 'overcome', 'overhead', 'but', 'current', 'custom', 'due', 'fundamental', 'guaranteeing', 'multi', 'multiple', 'multiplexing', 'nulling', 'number', 'out', 'output', 'pursue', 'success', 'suitable', 'support', 'suppress', 'tunable', 'at', 'attenuation', 'it', 'its', 'stack', 'state', 'station', 'stations', 'statutory', 'strong', 'ttd', 'utilization', 'utilizing', 'as', 'estimation', 'is', 'nsf', 'use', 'users', 'using', 'architecture', 'are', 'array', 'arrays', 'art', 'br', 'broader', 'criteria', 'cross', 'frame', 'framework', 'free', 'frequencies', 'frequency', 'from', 'front', 'practical', 'present', 'problems', 'processing', 'prohibitive', 'project', 'propagation', 'proposed', 'protocol', 'protocols', 'prototyping', 'training', 'transparent', 'trend', 'true', 'equipped', 'squint', 'ap', 'approach', 'approaches', 'optimization', 'spatial', 'spectrum', 'co', 'communication', 'communications', 'compensate', 'compensating', 'complemented', 'conditions', 'connectivity', 'consumption', 'continue', 'cooperative', 'coordination', 'cost', 'costs', 'focus', 'for', 'format', 'foundation', 'four', 'goal', 'however', 'loss', 'low', 'modulated', 'most', 'nodes', 'not', 'novel', 'point', 'power', 'role', 'solutions', 'sophisticated', 'to', 'together', 'work', 'world', 'worthy', 'an', 'and', 'antenna', 'antennas', 'enables', 'enabling', 'end', 'entire', 'in', 'including', 'increases', 'inefficient', 'influence', 'infrastructure', 'initial', 'input', 'integrate', 'integration', 'intellectual', 'inter', 'interference', 'interferers', 'into', 'involve', 'involves', 'knowledge', 'on', 'only', 'uncoordinated', 'unfavorable', 'unknown', 'amenable', 'emerging', 'impacts', 'implementation', 'importance', 'important', 'improve', 'mmw', 'small', 'algorithm', 'algorithms', 'allows', 'also', 'although', 'blind', 'element', 'flexibility', 'played', 'aimed', 'aims', 'bic', 'circuits', 'directional', 'directionality', 'disciplinary', 'distortion', 'fi', 'given', 'high', 'highly', 'limited', 'link', 'millimeter', 'mimo', 'mission', 'pilot', 'signal', 'signals', 'significant', 'simultaneous', 'time', 'via', 'wi', 'wide', 'wideband', 'widely', 'will', 'wireless', 'with', 'challenge', 'challenges', 'channel', 'characteristics', 'phased', 'sharing', 'shortage', 'that', 'the', 'their', 'them', 'theme', 'theory', 'there', 'therefore', 'they', 'this', 'three', 'through', 'thrust', 'thrusts', 'when', 'where', '2g', '3g', '4g', '5g', '6ghz', 'effective', 'efficiency', 'effort', 'of', 'rf', 'be', 'beam', 'beamforming', 'beams', 'been', 'below', 'between', 'cell', 'cellular', 'central', 'decode', 'deemed', 'delay', 'demonstrate', 'dense', 'densification', 'dependent', 'deployment', 'deployments', 'design', 'detection', 'develop', 'developed', 'feasibility', 'generations', 'generic', 'heterogeneous', 'key', 'level', 'leveraging', 'merit', 'network', 'networking', 'networks', 'next', 'real', 'receiver', 'recent', 'reconfigurable', 'reduce', 'reduced', 'reflects', 'require', 'research', 'review', 'several', 'techniques', 'technologies', 'technology', 'testbed', 'vectors', 'weight', 'well', 'adaptive', 'advance', 'advances', 'access', 'achieve', 'scheme', 'ability', 'objective', 'bandwidth', 'base', 'based', 'can', 'cancellation', 'carried', 'data', 'face', 'faced', 'facilitate', 'fast', 'gain', 'has', 'have', 'large', 'latency', 'layer', 'main', 'maintenance', 'management', 'many', 'narrow', 'path', 'radio', 'radios', 'same', 'tame', 'validate', 'wave', 'waveform', '28ghz', '16']
# Cluster 10:
# ['dynamically', 'example', 'exceeding', 'experimentally', 'exploited', 'award', 'switching', 'two', 'available', 'evaluation', 'even', 'building', 'multi', 'multiplexing', 'support', 'supports', 'surfaces', 'at', 'its', 'standard', 'statutory', 'steer', 'steerable', 'steering', 'stream', 'study', 'is', 'nsf', 'user', 'using', 'architectural', 'architecture', 'area', 'br', 'broader', 'criteria', 'frequency', 'from', 'or', 'order', 'presence', 'project', 'promises', 'proof', 'property', 'provide', 'provides', 'transmission', 'spatial', 'spectral', 'spectrum', 'specular', 'up', 'commercially', 'communication', 'components', 'concept', 'control', 'coupling', 'following', 'for', 'foundation', 'local', 'low', 'mobile', 'mobility', 'non', 'novel', 'populations', 'to', 'towards', 'worthy', 'an', 'and', 'angle', 'angular', 'enable', 'engineered', 'environmental', 'in', 'ingredient', 'integrated', 'intellectual', 'into', 'under', 'underlying', 'uninterrupted', 'unique', 'emitted', 'empirical', 'impacts', 'implementation', 'smart', 'already', 'blocks', 'clients', 'electrical', 'elements', 'plane', 'wlan', 'wlans', 'aims', 'different', 'directional', 'directionality', 'fi', 'first', 'gigabit', 'gigabits', 'gigahertz', 'high', 'highly', 'kind', 'limited', 'limits', 'line', 'links', 'mission', 'pixelated', 'sight', 'signature', 'simultaneous', 'sixth', 'time', 'via', 'wi', 'will', 'wireless', 'with', 'ghz', 'physical', 'that', 'the', 'third', 'this', 'through', 'thrust', 'thrusts', 'thus', 'thz', 'whether', 'of', 'be', 'beam', 'beams', 'been', 'deemed', 'demonstration', 'dense', 'density', 'derived', 'design', 'developed', 'generation', 'key', 'leaky', 'merit', 'meta', 'metasurface', 'meters', 'methodology', 'network', 'networks', 'new', 'next', 'per', 'realize', 'reception', 'reflecting', 'reflection', 'reflects', 'research', 'result', 'review', 'sec', 'second', 'selective', 'terabit', 'terahertz', 'adaptive', 'identifying', 'access', 'achievable', 'scale', 'scaling', 'objective', 'tb', 'data', 'each', 'has', 'large', 'latency', 'latest', 'magnitude', 'many', 'namely', 'packing', 'path', 'paths', 'rainbow', 'range', 'rate', 'rates', 'targeting', 'targets', 'waveguide', '100', '500', '60']
# Cluster 11:
# ['by', 'dynamically', 'dynamics', 'synthesis', 'system', 'systems', 'exchange', 'execute', 'existing', 'experience', 'experimental', 'experts', 'explainable', 'explicit', 'explore', 'exploring', 'express', 'extra', 'extremely', 'award', 'switch', 'switches', 'two', 'www', 'average', 'evaluate', 'evaluated', 'evaluation', 'events', 'ever', 'evolving', 'over', 'overhead', 'augmented', 'buffer', 'build', 'burden', 'bursty', 'business', 'but', 'due', 'during', 'fully', 'fundamental', 'further', 'human', 'just', 'much', 'multimedia', 'multiple', 'out', 'outages', 'outreach', 'pursues', 'pushing', 'quality', 'quantify', 'rule', 'running', 'subjectively', 'substrates', 'successful', 'such', 'suite', 'support', 'surging', 'at', 'attack', 'attempts', 'https', 'it', 'other', 'started', 'stations', 'statistical', 'statutory', 'still', 'streaming', 'structures', 'students', 'studies', 'utilization', 'utilize', 'as', 'aspect', 'aspects', 'assist', 'assisted', 'cs', 'especially', 'essential', 'is', 'isn', 'issues', 'nsf', 'use', 'user', 'users', 'using', 'ar', 'are', 'area', 'areas', 'br', 'breaches', 'broad', 'broader', 'broadly', 'broken', 'criteria', 'critical', 'driving', 'framework', 'frameworks', 'frequent', 'from', 'frontier', 'graduate', 'grained', 'granular', 'growing', 'or', 'oriented', 'original', 'practical', 'prediction', 'preliminary', 'presentations', 'prevailing', 'prevention', 'priorities', 'privacy', 'problem', 'process', 'processing', 'processors', 'program', 'programmability', 'programmable', 'programming', 'programs', 'progresses', 'project', 'proliferation', 'promising', 'proposal', 'proposed', 'proposes', 'protection', 'protocols', 'prototype', 'provide', 'providers', 'provides', 'providing', 'provisioning', 'trade', 'trading', 'traffic', 'train', 'trained', 'transfer', 'true', 'try', 'vr', 'write', 'writing', 'equipped', 'equivalence', 'api', 'applications', 'approach', 'approaches', 'fpgas', 'open', 'operational', 'operator', 'operators', 'opportunities', 'opposite', 'optimal', 'optimization', 'optimizes', 'spans', 'specializing', 'specific', 'specifically', 'specify', 'spectrum', 'speed', 'speeding', 'up', 'update', 'boundaries', 'code', 'collaboration', 'collaborative', 'collection', 'combination', 'communicate', 'communication', 'community', 'compatible', 'compensate', 'compiler', 'compilers', 'complement', 'completion', 'complexity', 'complicated', 'component', 'compressive', 'computation', 'computational', 'computer', 'computers', 'concepts', 'concern', 'concerns', 'conditions', 'conducted', 'configurations', 'configure', 'congested', 'congestion', 'connect', 'connected', 'connectivity', 'consistent', 'constraints', 'contains', 'content', 'contention', 'context', 'contextual', 'continue', 'contribute', 'contributed', 'contributions', 'control', 'cooperation', 'cooperative', 'copies', 'correctness', 'cost', 'costs', 'coverage', 'do', 'domain', 'down', 'for', 'formal', 'fortify', 'forwarding', 'foundation', 'foundational', 'goal', 'good', 'homes', 'hop', 'how', 'however', 'load', 'loss', 'low', 'lower', 'mobile', 'model', 'modeling', 'models', 'modern', 'more', 'most', 'mostly', 'motivated', 'moves', 'no', 'noticeable', 'notions', 'novel', 'now', 'points', 'poor', 'pose', 'potential', 'powerful', 'qoe', 'roads', 'robust', 'roles', 'routers', 'so', 'society', 'software', 'solutions', 'solving', 'some', 'somewhat', 'source', 'to', 'today', 'together', 'tom', 'too', 'tools', 'work', 'workload', 'worthy', 'would', 'youtube', 'an', 'analysis', 'and', 'another', 'enable', 'encrypted', 'encryption', 'end', 'energy', 'engage', 'engineering', 'engineers', 'enhance', 'enhancement', 'in', 'incidents', 'include', 'incorporate', 'incorporation', 'increase', 'increasing', 'increasingly', 'incrementally', 'incur', 'individual', 'industry', 'inference', 'information', 'informed', 'infrastructure', 'ingredient', 'inherent', 'innovative', 'institute', 'integral', 'integrates', 'intellectual', 'intends', 'inter', 'internet', 'inter ...
# Cluster 12:
# ['by', 'cycling', 'dynamically', 'dynamics', 'synchronized', 'system', 'systems', 'example', 'expected', 'expediting', 'expense', 'expensive', 'experiments', 'expiry', 'exploited', 'exploiting', 'explosive', 'extends', 'extent', 'award', 'aware', 'awareness', 'available', 'evaluation', 'even', 'evolution', 'evolutionary', 'over', 'automated', 'automation', 'autonomous', 'building', 'built', 'curriculum', 'due', 'during', 'duty', 'eun', 'europe', 'fully', 'function', 'fundamental', 'future', 'guaranteeing', 'guidelines', 'huge', 'hundreds', 'multi', 'multiple', 'number', 'numerous', 'outcome', 'outreach', 'public', 'publicly', 'rumor', 'subject', 'successful', 'such', 'suite', 'support', 'at', 'attacks', 'ethereum', 'https', 'it', 'its', 'stack', 'stage', 'standards', 'state', 'statutory', 'still', 'strategic', 'structure', 'student', 'students', 'study', 'studying', 'as', 'especially', 'estimate', 'estimation', 'is', 'isa100', 'issue', 'nsf', 'us', 'usable', 'use', 'users', 'uses', 'using', 'are', 'area', 'areas', 'arizona', 'br', 'break', 'bridge', 'brings', 'broader', 'criteria', 'crucial', 'cryptocurrencies', 'fraction', 'framework', 'from', 'frontiers', 'graduate', 'graduation', 'graph', 'ground', 'groups', 'growth', 'or', 'practice', 'predict', 'pricing', 'problems', 'process', 'products', 'project', 'prolific', 'propagation', 'proposed', 'proposes', 'protocol', 'provide', 'providing', 'trained', 'transactions', 'transforming', 'transient', 'triggered', 'square', 'applications', 'approaches', 'epidemic', 'epidemics', 'epidemiology', 'lpwan', 'lpwans', 'open', 'opposed', 'optimization', 'optimize', 'specially', 'spread', 'spreading', 'bodies', 'both', 'bound', 'codes', 'codesign', 'collaborative', 'colorado', 'com', 'combat', 'combination', 'communication', 'community', 'companies', 'compared', 'compete', 'competitiveness', 'complete', 'complex', 'complexity', 'comprehensive', 'concept', 'conduct', 'configuration', 'connected', 'connections', 'connectivity', 'consensus', 'consider', 'considering', 'constraints', 'consumption', 'contribute', 'contributions', 'control', 'cost', 'costs', 'could', 'course', 'cover', 'following', 'footprint', 'for', 'form', 'formation', 'foundation', 'foundations', 'goal', 'google', 'hop', 'hosted', 'how', 'however', 'iot', 'jointly', 'local', 'locations', 'long', 'loops', 'lora', 'low', 'modeling', 'models', 'monitor', 'more', 'node', 'noisy', 'north', 'poses', 'posing', 'positioned', 'possible', 'potentially', 'power', 'routing', 'social', 'society', 'solutions', 'some', 'source', 'to', 'today', 'together', 'women', 'work', 'worm', 'worthy', 'an', 'analysis', 'analytical', 'and', 'any', 'cns', 'enable', 'enabling', 'encouraging', 'end', 'energy', 'environment', 'in', 'including', 'incomplete', 'inconvenient', 'increase', 'industrial', 'industries', 'inexpensive', 'infected', 'inference', 'influence', 'information', 'input', 'insightful', 'instant', 'institute', 'integrate', 'integrating', 'intellectual', 'inter', 'interests', 'internet', 'into', 'investigate', 'investigators', 'involve', 'on', 'under', 'undergraduate', 'underlying', 'underrepresented', 'understand', 'understanding', 'unique', 'university', 'unsuited', 'impact', 'impacts', 'important', 'smart', 'algorithmic', 'algorithms', 'all', 'allocation', 'also', 'blockchain', 'blocks', 'class', 'closing', 'florida', 'global', 'plants', 'sleeping', 'slow', 'djyang', 'aims', 'big', 'bitcoin', 'difficult', 'disciplinary', 'disseminating', 'dissemination', 'distribution', 'diverse', 'field', 'findings', 'five', 'giving', 'high', 'highly', 'hinders', 'iiot', 'kilometers', 'lies', 'likelihood', 'limitations', 'literature', 'microeconomics', 'miles', 'mines', 'minimum', 'misinformation', 'mission', 'mitigate', 'oil', 'pipelines', 'rich', 'rigorous', 'rise', 'significant', 'silos', 'simple', 'since', 'sites', 'time', 'times', 'view', 'viral', 'wide', 'will', 'wireless', 'wirelesshart', 'with', 'without', 'yield', 'chain', 'challenge', 'challenge ...
# Cluster 13:
# ...
# Cluster 16:
# ['by', 'exploiting', 'extracting', 'extreme', 'award', 'evaluated', 'evaluation', 'everything', 'current', 'curriculum', 'further', 'multipath', 'outcome', 'public', 'successful', 'such', 'suite', 'support', 'supporting', 'it', 'state', 'statutory', 'studies', 'as', 'nsf', 'usage', 'uses', 'using', 'area', 'art', 'br', 'broader', 'criteria', 'cross', 'driven', 'drones', 'friendly', 'graduate', 'orbit', 'predict', 'predicted', 'predictive', 'project', 'proper', 'proposed', 'proposes', 'prototype', 'traces', 'transformative', 'approaches', 'operational', 'optimization', 'optimizations', 'speed', 'bottlenecks', 'collaborate', 'doppler', 'for', 'forward', 'foundation', 'locality', 'looking', 'low', 'mobility', 'more', 'novel', 'roles', 'software', 'solution', 'to', 'work', 'worthy', 'analyze', 'and', 'enable', 'enabling', 'ensure', 'in', 'incorporated', 'industry', 'infrastructure', 'intellectual', 'interpretable', 'into', 'under', 'undergraduate', 'unveils', 'emerging', 'emulation', 'impact', 'impacts', 'allocation', 'also', 'client', 'clients', 'eliminates', 'ml', 'slow', 'distributed', 'finally', 'first', 'high', 'limitations', 'mimo', 'mission', 'significantly', 'simplified', 'wide', 'will', 'wireless', 'with', 'channel', 'the', 'their', 'them', 'then', 'this', 'through', '4g', '5g', 'efficient', 'if', 'of', 'be', 'been', 'beyond', 'deemed', 'deficiencies', 'defined', 'delay', 'design', 'designs', 'develops', 'feedback', 'help', 'learning', 'merit', 'networks', 'perform', 'performance', 'reflects', 'release', 'reliability', 'research', 'researchers', 'resource', 'review', 'temporal', 'vehicle', 'yet', 'adaptation', 'adapts', 'advance', 'accurately', 'scale', 'scenarios', 'cannot', 'earth', 'fast', 'has', 'large', 'latency', 'layer', 'machine', 'many', 'maximize', 'radio', 'rails', 'rate', 'satellites', 'satisfactory', 'various', 'varying', 'way']
# Cluster 17:
# ['by', 'cyberinfrastructure', 'existing', 'expected', 'expensive', 'experimental', 'extending', 'award', 'two', 'average', 'evaluation', 'even', 'every', 'overall', 'burden', 'businesses', 'currently', 'due', 'multi', 'multiple', 'successfully', 'support', 'at', 'ethernet', 'it', 'its', 'other', 'statutory', 'stress', 'as', 'aspect', 'estimate', 'is', 'nsf', 'useful', 'using', 'architecture', 'br', 'broader', 'criteria', 'critical', 'dramatically', 'or', 'organizations', 'produced', 'project', 'providing', 'transceivers', 'transmission', 'traverse', 'equipment', 'approach', 'ip', 'open', 'optic', 'optical', 'span', 'spans', 'up', 'both', 'boundaries', 'coherent', 'collaboratively', 'conduct', 'connecting', 'connection', 'connections', 'connectivity', 'consists', 'contributions', 'controllers', 'cost', 'costs', 'do', 'domain', 'domains', 'domestically', 'focuses', 'for', 'foundation', 'however', 'more', 'not', 'oon', 'points', 'routers', 'so', 'software', 'source', 'to', 'today', 'together', 'tool', 'towards', 'work', 'world', 'worthy', 'an', 'and', 'any', 'enable', 'enabling', 'in', 'increase', 'increased', 'information', 'infrastructure', 'innovation', 'intellectual', 'interaction', 'internationally', 'internet', 'interoperable', 'into', 'investigation', 'on', 'one', 'underlie', 'amounts', 'emulator', 'impacts', 'improve', 'also', 'planning', 'bit', 'different', 'dissemination', 'fiber', 'life', 'like', 'mimics', 'mission', 'signal', 'signals', 'significantly', 'time', 'without', 'changing', 'characteristics', 'share', 'than', 'that', 'the', 'this', 'through', 'thus', 'while', 'whose', 'aging', 'effective', 'efficiency', 'efficient', 'of', 'been', 'behavior', 'between', 'decrease', 'deemed', 'defined', 'definition', 'deliver', 'demonstrate', 'deployed', 'deployments', 'design', 'developed', 'development', 'key', 'mechanical', 'merit', 'network', 'networking', 'networks', 'new', 'newly', 'people', 'per', 'performance', 'real', 'reflects', 'relevant', 'requiring', 'researchers', 'review', 'seamless', 'services', 'setting', 'techniques', 'technology', 'tele', 'telehealth', 'telemetric', 'telework', 'testbed', 'vendor', 'vendors', 'we', 'advanced', 'advantage', 'education', 'sdn', 'access', 'account', 'accurately', 'acquiring', 'across', 'scalability', 'ability', 'objective', 'bandwidth', 'based', 'can', 'factor', 'factors', 'has', 'layer', 'layers', 'maintaining', 'nation', 'pace', 'takes', 'taking', 'validation', 'vast']
# Cluster 18:
# ['by', 'cyberinfrastructure', 'cybersecurity', 'dynamic', 'dynamically', 'hybrid', 'synchronize', 'system', 'systems', 'typical', 'axes', 'example', 'excellent', 'exchange', 'executed', 'exercise', 'exist', 'existing', 'expanding', 'expected', 'experience', 'experimental', 'experimentally', 'experimentation', 'experiments', 'exploits', 'exploration', 'explore', 'explored', 'explores', 'expressive', 'extensive', 'extract', 'award', 'away', 'gwc', 'gwinnett', 'owc', 'swiftly', 'two', 'www', 'available', 'evaluate', 'evaluation', 'even', 'event', 'ever', 'evermore', 'every', 'iv', 'oven', 'over', 'overall', 'overarching', 'overhead', 'overlay', 'overlaying', 'uv', 'augmented', 'automatically', 'automation', 'autonomous', 'building', 'built', 'business', 'businesses', 'but', 'cubesats', 'cubic', 'current', 'curriculum', 'custom', 'customized', 'cutting', 'due', 'duration', 'fueled', 'fulfill', 'functions', 'fundamental', 'fundamentally', 'further', 'fusion', 'future', 'guarantees', 'guided', 'guiding', 'hub', 'human', 'humans', 'much', 'multi', 'multipath', 'multiple', 'mundane', 'our', 'out', 'outcome', 'outcomes', 'output', 'outreach', 'public', 'publication', 'publications', 'publicly', 'purpose', 'pushing', 'quality', 'quasistatic', 'questionable', 'runtime', 'substantially', 'subtracting', 'success', 'successful', 'such', 'suffice', 'summary', 'summer', 'support', 'supported', 'surface', 'surpass', 'surrounding', 'surroundings', 'turbidity', 'at', 'atlanta', 'atmospheric', 'attain', 'attempts', 'attendees', 'attributed', 'etc', 'http', 'https', 'it', 'iterative', 'its', 'itself', 'other', 'standard', 'starved', 'state', 'stateful', 'station', 'stations', 'statutory', 'stay', 'steering', 'steps', 'strategic', 'strengthen', 'stringent', 'strong', 'structural', 'student', 'students', 'studies', 'study', 'utilize', 'as', 'asks', 'assisted', 'associated', 'establish', 'establishing', 'is', 'issues', 'nsf', 'us', 'use', 'used', 'useful', 'user', 'users', 'using', 'usually', 'ar', 'arbitrary', 'architecture', 'are', 'area', 'argues', 'around', 'art', 'br', 'brain', 'bridging', 'bring', 'bringing', 'broad', 'broadband', 'broader', 'broadly', 'create', 'creates', 'criteria', 'critical', 'crop', 'crystal', 'draw', 'drivers', 'driving', 'drone', 'drones', 'drugs', 'framework', 'free', 'frequencies', 'frequency', 'from', 'front', 'graduate', 'grained', 'granularity', 'graph', 'greater', 'green', 'ground', 'groups', 'grow', 'growth', 'or', 'orbit', 'order', 'orders', 'org', 'organ', 'organizations', 'organize', 'orientations', 'practical', 'practices', 'practitioners', 'pre', 'preceding', 'precisely', 'precision', 'predict', 'preferably', 'preliminary', 'presence', 'presentations', 'presents', 'preserved', 'preventing', 'prevents', 'principles', 'prior', 'privacy', 'probability', 'probing', 'problem', 'problems', 'processing', 'program', 'programmability', 'programmable', 'programmatically', 'programming', 'programs', 'progresses', 'project', 'projects', 'proliferation', 'promising', 'promote', 'propagate', 'properties', 'proposal', 'proposed', 'prototypes', 'provide', 'provides', 'providing', 'track', 'tracking', 'trade', 'traditional', 'traffic', 'training', 'transceiver', 'transceivers', 'transferring', 'transform', 'transformative', 'transformed', 'transition', 'transitions', 'transmissions', 'transmitter', 'transmitting', 'transport', 'traveling', 'urban', 'vr', 'equipment', 'equipped', 'app', 'appalachian', 'applicable', 'application', 'applications', 'applying', 'approach', 'approaches', 'apps', 'april', 'lp', 'open', 'operate', 'operation', 'operational', 'operations', 'operators', 'opioid', 'opportunities', 'opportunity', 'optical', 'optimization', 'optimize', 'optimized', 'space', 'sparse', 'spatial', 'specific', 'specified', 'spectrum', 'speed', 'spherical', 'up', 'body', 'both', 'bottleneck', 'co', 'code', 'codebase', 'collaborate', 'collaboration', 'collaborations', 'collaborative', 'collated', 'collect', 'collection', 'colle ...
# Cluster 19:
# ['by', 'dynamic', 'dynamically', 'synergistic', 'system', 'systems', 'typically', 'execution', 'existing', 'expensive', 'experience', 'exploration', 'explore', 'explores', 'expose', 'extend', 'extensions', 'extensively', 'extraction', 'award', 'aware', 'awe', 'switch', 'availability', 'available', 'evaluated', 'evaluates', 'evaluation', 'overheads', 'augmented', 'automatically', 'build', 'but', 'currently', 'curriculum', 'duration', 'full', 'functionality', 'fundamentally', 'furthermore', 'guide', 'human', 'judiciously', 'just', 'multi', 'multiple', 'must', 'outreach', 'public', 'publication', 'publishers', 'purdue', 'quality', 'queries', 'query', 'run', 'running', 'runtime', 'rural', 'substantial', 'success', 'such', 'suite', 'summaries', 'support', 'surveillance', 'tune', 'at', 'attract', 'html', 'http', 'https', 'it', 'its', 'stack', 'statutory', 'steady', 'steerable', 'storage', 'stores', 'strategies', 'streaming', 'streams', 'stressing', 'strong', 'structures', 'students', 'studies', 'utilize', 'as', 'cs', 'is', 'isl', 'nsf', 'nsl', 'usc', 'use', 'user', 'users', 'using', 'architectural', 'are', 'areas', 'arrays', 'artifacts', 'br', 'breadth', 'bridge', 'broader', 'broken', 'create', 'criteria', 'critical', 'cross', 'drastically', 'drive', 'driving', 'frame', 'framework', 'freshman', 'from', 'graduate', 'groups', 'growth', 'or', 'order', 'organizations', 'organize', 'practical', 'practitioners', 'predict', 'predictable', 'preserving', 'previously', 'privacy', 'profiling', 'prohibitively', 'project', 'projects', 'promise', 'proper', 'proposed', 'provide', 'provided', 'provisioning', 'traces', 'tracking', 'traffic', 'training', 'transform', 'transforming', 'traverse', 'application', 'applications', 'approach', 'appropriate', 'optimization', 'optimizations', 'optimize', 'optimizing', 'span', 'spatial', 'specified', 'specify', 'sports', 'board', 'both', 'coding', 'collaborations', 'collaborators', 'collect', 'collected', 'collection', 'college', 'communities', 'community', 'comprehensively', 'comprising', 'computation', 'compute', 'computer', 'computing', 'condition', 'connected', 'considering', 'constraints', 'construction', 'consume', 'consumption', 'content', 'continuously', 'convene', 'cope', 'correlation', 'cost', 'costs', 'counting', 'coupled', 'couples', 'course', 'do', 'domains', 'focus', 'focused', 'for', 'form', 'forms', 'foster', 'foundation', 'foundational', 'goal', 'iot', 'joint', 'loads', 'low', 'lower', 'modifications', 'monitoring', 'more', 'most', 'motivates', 'not', 'novel', 'point', 'population', 'populations', 'potential', 'software', 'solutions', 'sophisticated', 'to', 'today', 'top', 'women', 'work', 'workshops', 'worthy', 'an', 'analysis', 'analytical', 'analytics', 'and', 'angle', 'answers', 'dnns', 'enable', 'enables', 'enabling', 'encoding', 'end', 'ends', 'energy', 'engage', 'engineering', 'enhance', 'enhancements', 'environments', 'in', 'inaccurate', 'include', 'includes', 'including', 'incomplete', 'incorporate', 'increased', 'increasing', 'increasingly', 'industrial', 'industries', 'inefficient', 'information', 'informed', 'infrastructure', 'insight', 'insights', 'instead', 'instructions', 'intellectual', 'intelligent', 'intensive', 'interaction', 'interactions', 'interactively', 'interactivity', 'interdisciplinary', 'interest', 'internet', 'into', 'investigating', 'involve', 'involves', 'on', 'only', 'under', 'undergraduate', 'undergraduates', 'underlying', 'underrepresented', 'understand', 'underutilized', 'unfortunately', 'unusable', 'unused', 'emergence', 'emerging', 'emulation', 'immersive', 'impact', 'impacts', 'implement', 'impractical', 'improve', 'improvements', 'improves', 'algorithms', 'allocate', 'allocation', 'allowing', 'along', 'also', 'altering', 'classifies', 'client', 'cloud', 'clusters', 'place', 'plates', 'players', 'slice', 'aim', 'aims', 'differencing', 'different', 'dimensional', 'directions', 'directly', 'disaster', 'distributed', 'diverse', 'either', 'field', 'finally', ' ...

# %% [markdown]
# ##### Top 10 words

# %%
# Transform the cluster centers back into a list of words
cluster_words = vectorizer.inverse_transform(kmeans.cluster_centers_)

# Sort the words in each cluster by their TF-IDF scores
sorted_words = [sorted(words, key=lambda x: x[1], reverse=True) for words in cluster_words]

# Print the top 10 words for each cluster
for i in range(len(sorted_words)):
    print(f"Cluster {i}:")
    print(sorted_words[i][:10])
# Out:
# Cluster 0:
# ['by', 'dynamics', 'symbiotically', 'system', 'existing', 'experience', 'experiments', 'expose', 'extended', 'award']
# Cluster 1:
# ['by', 'systems', 'excess', 'expected', 'experience', 'award', 'two', 'evaluation', 'culminate', 'current']
# Cluster 2:
# ['by', 'cyberphysical', 'cycle', 'dynamic', 'dynamically', 'dynamics', 'system', 'systematic', 'systematically', 'systems']
# Cluster 3:
# ['by', 'dynamic', 'dynamics', 'eyes', 'hybrid', 'hyperdimensional', 'symbol', 'synergy', 'system', 'systems']
# Cluster 4:
# ['by', 'system', 'systems', 'existing', 'expenditure', 'experienced', 'expertise', 'exploration', 'explore', 'exploring']
# Cluster 5:
# ['by', 'dynamic', 'dynamics', 'hybrid', 'system', 'systems', 'except', 'exchange', 'execution', 'exhaustive']
# Cluster 6:
# ['by', 'symposium', 'system', 'systems', 'types', 'existing', 'experience', 'explore', 'expose', 'exposed']
# Cluster 7:
# ['by', 'dynamic', 'system', 'systems', 'example', 'exceed', 'exciting', 'existing', 'experiments', 'exploit']
# Cluster 8:
# ['by', 'bypass', 'bytecode', 'cyber', 'cyberattacks', 'dynamic', 'dynamically', 'dynamics', 'synchronizing', 'synchronous']
# Cluster 9:
# ['by', 'system', 'systems', 'exist', 'existing', 'expected', 'experimental', 'experimentally', 'experimentation', 'exploitation']
# Cluster 10:
# ['dynamically', 'example', 'exceeding', 'experimentally', 'exploited', 'award', 'switching', 'two', 'available', 'evaluation']
# Cluster 11:
# ['by', 'dynamically', 'dynamics', 'synthesis', 'system', 'systems', 'exchange', 'execute', 'existing', 'experience']
# Cluster 12:
# ['by', 'cycling', 'dynamically', 'dynamics', 'synchronized', 'system', 'systems', 'example', 'expected', 'expediting']
# Cluster 13:
# ['by', 'synergistic', 'existing', 'exploration', 'award', 'evaluation', 'building', 'built', 'future', 'pursues']
# Cluster 14:
# ['ay', 'by', 'dynamic', 'synergistic', 'system', 'systems', 'types', 'exceed', 'exhaustive', 'existing']
# Cluster 15:
# ['by', 'dynamic', 'dynamically', 'dynamics', 'hybrid', 'system', 'systems', 'example', 'exceedingly', 'execute']
# Cluster 16:
# ['by', 'exploiting', 'extracting', 'extreme', 'award', 'evaluated', 'evaluation', 'everything', 'current', 'curriculum']
# Cluster 17:
# ['by', 'cyberinfrastructure', 'existing', 'expected', 'expensive', 'experimental', 'extending', 'award', 'two', 'average']
# Cluster 18:
# ['by', 'cyberinfrastructure', 'cybersecurity', 'dynamic', 'dynamically', 'hybrid', 'synchronize', 'system', 'systems', 'typical']
# Cluster 19:
# ['by', 'dynamic', 'dynamically', 'synergistic', 'system', 'systems', 'typically', 'execution', 'existing', 'expensive']

# %% [markdown]
# ##### Unique Words

# %%
# Transform the cluster centers back into a list of words
cluster_words = vectorizer.inverse_transform(kmeans.cluster_centers_)

# Sort the words in each cluster by their TF-IDF scores
sorted_words = [sorted(words, key=lambda x: x[1], reverse=True) for words in cluster_words]

# Get the unique words for each cluster
seen_words = set()
unique_words = []
for i in range(len(sorted_words)):
    cluster_words = sorted_words[i]
    unique_words.append([word for word in cluster_words if word not in seen_words])
    seen_words.update(unique_words[i])

# Print the unique words for each cluster
for i in range(len(unique_words)):
    print(f"Cluster {i}:")
    print(unique_words[i][:10])
# Out:
# Cluster 0:
# ['by', 'dynamics', 'symbiotically', 'system', 'existing', 'experience', 'experiments', 'expose', 'extended', 'award']
# Cluster 1:
# ['systems', 'excess', 'expected', 'two', 'culminate', 'current', 'fully', 'fundamental', 'much', 'multitude']
# Cluster 2:
# ['cyberphysical', 'cycle', 'dynamic', 'dynamically', 'systematic', 'systematically', 'typically', 'exacerbates', 'examples', 'execution']
# Cluster 3:
# ['eyes', 'hybrid', 'hyperdimensional', 'symbol', 'synergy', 'types', 'examine', 'examines', 'example', 'exhibit']
# Cluster 4:
# ['expenditure', 'experienced', 'expertise', 'exploration', 'exploring', 'everyday', 'overarching', 'oversimplify', 'further', 'outside']
# Cluster 5:
# ['except', 'exchange', 'exhaustive', 'exist', 'exists', 'expensive', 'exponential', 'extent', 'extracted', 'extraordinary']
# Cluster 6:
# ['symposium', 'exposed', 'exposure', 'extends', 'tx', 'awards', 'twenty', 'event', 'audience', 'austin']
# Cluster 7:
# ['exceed', 'exciting', 'exploits', 'explores', 'automotive', 'culminating', 'functions', 'publication', 'qualcomm', 'strictly']
# Cluster 8:
# ['bypass', 'bytecode', 'cyber', 'cyberattacks', 'synchronizing', 'synchronous', 'exactly', 'executed', 'existence', 'expand']
# Cluster 9:
# ['experimental', 'experimentally', 'experimentation', 'exploiting', 'avoidance', 'evidenced', 'evolution', 'guaranteeing', 'multiplexing', 'nulling']
# Cluster 10:
# ['exceeding', 'exploited', 'surfaces', 'steer', 'steerable', 'steering', 'stream', 'architectural', 'promises', 'proof']
# Cluster 11:
# ['synthesis', 'execute', 'experts', 'explainable', 'express', 'extra', 'average', 'buffer', 'burden', 'bursty']
# Cluster 12:
# ['cycling', 'synchronized', 'expediting', 'expense', 'expiry', 'explosive', 'duty', 'eun', 'europe', 'guidelines']
# Cluster 13:
# ['synergistic', 'qualified', 'episodic', 'conceptual', 'configuring', 'continued', 'followed', 'enhancing', 'enriched', 'dino']
# Cluster 14:
# ['ay', 'expenditures', 'awakening', 'evacuation', 'duplex', 'pursued', 'question', 'sufficient', 'tutorials', 'attenuations']
# Cluster 15:
# ['exceedingly', 'expedite', 'explicitly', 'swarm', 'assume', 'critic', 'drastically', 'drills', 'erasure', 'orchestration']
# Cluster 16:
# ['everything', 'friendly', 'orbit', 'proper', 'optimizations', 'bottlenecks', 'collaborate', 'doppler', 'locality', 'incorporated']
# Cluster 17:
# ['cyberinfrastructure', 'every', 'successfully', 'ethernet', 'traverse', 'optic', 'controllers', 'domestically', 'oon', 'internationally']
# Cluster 18:
# ['cybersecurity', 'synchronize', 'typical', 'axes', 'excellent', 'exercise', 'expanding', 'explored', 'extract', 'away']
# Cluster 19:
# ['extensions', 'extensively', 'awe', 'evaluates', 'guide', 'judiciously', 'publishers', 'purdue', 'summaries', 'surveillance']

# %% [markdown]
# #### Names for each cluster based on their top unique words

# %%
# Transform the cluster centers back into a list of words
cluster_words = vectorizer.inverse_transform(kmeans.cluster_centers_)

# Sort the words in each cluster by their TF-IDF scores
sorted_words = [sorted(words, key=lambda x: x[1], reverse=True) for words in cluster_words]

# Get the unique words for each cluster
seen_words = set()
unique_words = []
for i in range(len(sorted_words)):
    cluster_words = sorted_words[i]
    unique_words.append([word for word in cluster_words if word not in seen_words])
    seen_words.update(unique_words[i])

# Generate a name for each cluster based on its top words
cluster_names = []
for i in range(len(unique_words)):
    cluster_name = " ".join(unique_words[i][:3])
    cluster_names.append(cluster_name)

# Print the cluster names
print(cluster_names)
# Out:
# ['by dynamics symbiotically', 'systems excess expected', 'cyberphysical cycle dynamic', 'eyes hybrid hyperdimensional', 'expenditure experienced expertise', 'except exchange exhaustive', 'symposium exposed exposure', 'exceed exciting exploits', 'bypass bytecode cyber', 'experimental experimentally experimentation', 'exceeding exploited surfaces', 'synthesis execute experts', 'cycling synchronized expediting', 'synergistic qualified episodic', 'ay expenditures awakening', 'exceedingly expedite explicitly', 'everything friendly orbit', 'cyberinfrastructure every successfully', 'cybersecurity synchronize typical', 'extensions extensively awe']

# %% [markdown]
# #### Top Titles for each Cluster

# %%
# Extract the titles from the data frame
titles = Awards2020['Title'].tolist()

# Vectorize the titles using TF-IDF
vectors = vectorizer.transform(titles)

# Assign each title to a cluster
cluster_labels = kmeans.predict(vectors)

# Compute the distances between each title and its cluster's centroid
distances = np.linalg.norm(vectors - kmeans.cluster_centers_[cluster_labels], axis=1)

# Zip the titles, cluster labels, and distances together
zipped = zip(titles, cluster_labels, distances)

# Sort the titles by their distances
sorted_titles = sorted(zipped, key=lambda x: x[2])

# Print the top 5 titles for each cluster
for i in range(kmeans.n_clusters):
    cluster_titles = [title for title, label, distance in sorted_titles if label == i]
    print(f"Cluster {i}:")
    print(cluster_titles[:5])
# Out:
# Cluster 0:
# []
# Cluster 1:
# ['EAGER: Information Theory: From Classical to Quantum', 'Collaborative Research: CNS Core: Medium: Design and Analysis of Quantum Networks for Entanglement Distribution', 'Collaborative Research: CNS Core: Medium: Design and Analysis of Quantum Networks for Entanglement Distribution', 'Collaborative Research: CNS Core: Medium: Design and Analysis of Quantum Networks for Entanglement Distribution']
# Cluster 2:
# ['CNS Core: Medium: Communication and Networking with Diffused Laser Light', 'CNS Core: Small: Design and Evaluation of Methods for Supporting Resilient and High-Availability Elastic Network Slicing', 'CNS Core: Small: New Caching Paradigms for Distributed and Dynamic Networks', 'CNS Core: Small: Dynamic and Composite Resource Management in Large-scale Industrial IoT Systems', 'SWIFT: SMALL: xNGRAN Navigating Spectral Utilization, LTE/WiFi Coexistence, and Cost Tradeoffs in Next Gen Radio Access Networks through Cross-Layer Design']
# Cluster 3:
# ['CAREER: Wireless Collaborative Mixed Reality Networking: Foundations and Algorithms for Joint Communication, Computation, and Learning', 'CAREER: Theory and Algorithms for Efficient Control of Wireless Networks with Jointly  Optimized Performance: High Throughput, Low Delay, and Low Complexity', 'Collaborative Research: MLWiNS: Distributed Learning over Multi-Access Channels: From Bandlimited Coordinate Descent to Gradient Sketching', 'Collaborative Research: MLWiNS: Distributed Learning over Multi-Access Channels: From Bandlimited Coordinate Descent to Gradient Sketching', 'Collaborative Research: MLWiNS: Deep Neural Networks Meet Physical LayerCommunications -- Learning with Knowledge of Structure']
# Cluster 4:
# ['Collaborative Research: SWIFT: LARGE: AI-Enabled Spectrum Coexistence between Active Communications and Passive Radio Services: Fundamentals, Testbed and Data', 'Collaborative Research: SWIFT: LARGE: AI-Enabled Spectrum Coexistence between Active Communications and Passive Radio Services: Fundamentals, Testbed and Data']
# Cluster 5:
# ['RAPID: Measuring the Effects of the COVID-19 Pandemic on Broadband Access Networks to Inform Robust Network Design', 'RAPID: Democratizing Genome Sequence Analysis for COVID-19 Using CloudLab', 'CNS Core: Small: Towards Hybrid Data Center Switching Using Partially Reconfigurable Circuit Switch']
# Cluster 6:
# ['NSF Student Travel Grant for 2020 ACM International Conference on Measurement and Modeling of Computer Systems (ACM SIGMETRICS 2020)', 'NSF Student Travel Grant for the 2020 IFIP Networking Conference (IFIP NETWORKING)', 'NSF Student Travel Grant for the 2020 IEEE International Conference on Network Protocols (ICNP)', "NSF Student Travel Grant for 2020 IEEE/IFIP Network Operations and Management Symposium (NOMS'2020)", 'NSF Student Travel Grant for 2020 21st ACM Workshop on Mobile Computing Systems and Applications (ACM HotMobile)']
# Cluster 7:
# ['Collaborative Research: CNS Core: Medium: Network-Enabled Cooperative Perception for Future Autonomous Vehicles', 'Collaborative Research: CNS Core: Medium: Network-Enabled Cooperative Perception for Future Autonomous Vehicles']
# Cluster 8:
# ['CAREER: Quality of Experience and Network Management in the Encrypted Internet', 'RAPID: Collaborative Research: The Internet under Widespread Shelter-in-Place: Resilience, Response, and Lessons for the Future', 'CNS Core: Medium: Bringing the Spatial Web to Life', 'RAPID: Bioinformatic Search for Epitope-based Molecular Mimicry in the SARS-CoV-2 Virus using Chameleon', 'CNS Core: Medium: The Synchronous Data Center']
# Cluster 9:
# []
# Cluster 10:
# []
# Cluster 11:
# ['MLWiNS: RL-based Self-driving Wireless Network Management System for QoE Optimization', 'CAREER: Leveraging Context-Aware Sensing to Enhance QoE for Mobile Users: A Practical Framework Design', 'CNS Core: Small: Autogenerating fast packet-processing code using program synthesis']
# Cluster 12:
# ['Collaborative Research: CNS Core: Small: Closing the Theory-Practice Gap in Understanding and Combating Epidemic Spreading on Resource-Constrained Large-Scale Networks', 'Collaborative Research: CNS Core: Small: Closing the Theory-Practice Gap in Understanding and Combating Epidemic Spreading on Resource-Constrained Large-Scale Networks']
# Cluster 13:
# ['Collaborative Research: MLWiNS: Dino-RL: A Domain Knowledge Enriched Reinforcement Learning Framework for Wireless Network Optimization', 'Collaborative Research: MLWiNS: Dino-RL: A Domain Knowledge Enriched Reinforcement Learning Framework for Wireless Network Optimization']
# Cluster 14:
# ['CAREER: Design, Analysis and Applications of mmWave Full-Duplex Wireless', 'Collaborative Research: CNS Core: Medium: Combating Latency and Disconnectivity in mmWave Networks: From Theory to Implementation', 'Collaborative Research: CNS Core: Medium: Combating Latency and Disconnectivity in mmWave Networks: From Theory to Implementation']
# Cluster 15:
# ['CAREER: Computing-Aware Network Optimization for Efficient Distributed Data Analytics at the Wireless Edge', 'CAREER: Computing-Aware Network Optimization for Efficient Distributed Data Analytics at the Wireless Edge', 'Collaborative Research: CNS Core: Small: Secure and Efficient Mobile Edge Computing in Wireless Heterogeneous Networks', 'Collaborative Research: CNS Core: Small: Secure and Efficient Mobile Edge Computing in Wireless Heterogeneous Networks', 'Collaborative Research: CNS Core: Small: Robust Resource Planning and Orchestration to Satisfy End-to-End SLA Requirements in Mobile Edge Networks']
# Cluster 16:
# []
# Cluster 17:
# []
# Cluster 18:
# ['The Future VR/AR Network -- Towards Virtual Human/Object Teleportation: NSF Workshop on Networked Virtual and Augmented Reality Communications', "CC* Integration-Large: An 'On-the-fly' Deeply Programmable End-to-end Network-Centric Platform for Edge-to-Core Workflows", 'Collaborative Research: CNS Core: Small: Retrofitting IoT Ecosystems with a Software-defined Overlay to Enforce Safety, Security, and Privacy Policies', 'Collaborative Research: CNS Core: Small: Retrofitting IoT Ecosystems with a Software-defined Overlay to Enforce Safety, Security, and Privacy Policies', 'Collaborative Research: CNS Core: Medium: OneDegree: Foundations and Methods for Imaging in mmWave Wireless Networks']
# Cluster 19:
# ['Collaborative Research: CNS Core: Medium: Cross-Layer Design of Video Analytics for the Internet of Things', 'Collaborative Research: CNS Core: Medium: Cross-Layer Design of Video Analytics for the Internet of Things', 'Collaborative Research: CNS Core: Medium: Panoptes: Next Generation Multi-Perspective Video Delivery at Internet Scale', 'Collaborative Research: CNS Core: Medium: Panoptes: Next Generation Multi-Perspective Video Delivery at Internet Scale', 'CNS Core: Small: Not All Cameras are Created Equal: Systems Support for Highly Adaptive Video Analytics Pipelines']
